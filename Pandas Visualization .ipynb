# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Load Dataset

# %%
df=pd.read_csv('modified_salarydata_pandas.csv')

# %%
df.head()
# Out:
#      CASE_NUMBER        CASE_STATUS CASE_RECEIVED_DATE DECISION_DATE  \
# 0  A-14190-86408  certified-expired           7/9/2014     12/4/2014
# 1  A-14126-66885  certified-expired           5/6/2014    10/20/2014
# 2  A-14226-98177          certified          8/14/2014     1/20/2015
# 3  A-14252-05264          certified           9/9/2014      2/3/2015
# 4  A-14147-72378  certified-expired          5/27/2014    10/14/2014
#
#    PREVAILING_WAGE_SUBMITTED  PAID_WAGE_SUBMITTED          JOB_TITLE  \
# 0                    98987.0              98987.0  software engineer
# 1                    98987.0              98987.0  software engineer
# 2                    71718.0              71718.0  software engineer
# 3                   108014.0             108014.0  software engineer
# 4                    71718.0              71718.0  software engineer
#
#   WORK_CITY EDUCATION_LEVEL_REQUIRED          PREVAILING_WAGE_SOC_TITLE  \
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
df=df.drop(['FULL_TIME_POSITION_Y_N'],axis=1)

# %%
df.shape
# Out:
# (167278, 15)

# %%
df.head()
# Out:
#      CASE_NUMBER        CASE_STATUS CASE_RECEIVED_DATE DECISION_DATE  \
# 0  A-14190-86408  certified-expired           7/9/2014     12/4/2014
# 1  A-14126-66885  certified-expired           5/6/2014    10/20/2014
# 2  A-14226-98177          certified          8/14/2014     1/20/2015
# 3  A-14252-05264          certified           9/9/2014      2/3/2015
# 4  A-14147-72378  certified-expired          5/27/2014    10/14/2014
#
#    PREVAILING_WAGE_SUBMITTED  PAID_WAGE_SUBMITTED          JOB_TITLE  \
# 0                    98987.0              98987.0  software engineer
# 1                    98987.0              98987.0  software engineer
# 2                    71718.0              71718.0  software engineer
# 3                   108014.0             108014.0  software engineer
# 4                    71718.0              71718.0  software engineer
#
#   WORK_CITY EDUCATION_LEVEL_REQUIRED          PREVAILING_WAGE_SOC_TITLE  \
# ...

# %% [markdown]
# # Data Viz. using Pandas

# %%
df.plot('PREVAILING_WAGE_SUBMITTED','PREVAILING_WAGE_PER_YEAR',kind='scatter')

# %%
df.plot()

# %%
df.plot('JOB_TITLE_SUBGROUP','PREVAILING_WAGE_SUBMITTED',kind='bar')

# %%
a=pd.read_csv(r'C:\Users\Mahaveer\Downloads\Datasets\data.csv')

# %%
a=a.set_index('id')

# %%
a.head()
# Out:
#    gender      bdate  educ  jobcat   salary salbegin  jobtime  prevexp
# id
# 1       m  03-Feb-52    15       3  $57,000  $27,000       98      144
# 2       m  23-May-58    16       1  $40,200  $18,750       98       36
# 3       f  26-Jul-29    12       1  $21,450  $12,000       98      381
# 4       f  15-Apr-47     8       1  $21,900  $13,200       98      190
# 5       m  09-Feb-55    15       1  $45,000  $21,000       98      138

# %%
a.plot()

# %%
a.plot('jobtime','prevexp',kind='scatter')

# %%
a.plot('jobcat','salary',kind='scatter')

# %%
a.plot.bar('jobcat','prevexp')

# %%
a[a.columns[3:6]] = a[a.columns[3:6]].replace('[\$,]', '', regex=True).astype(float)

# %%
a.head()
# Out:
#    gender      bdate  educ  jobcat   salary  salbegin  jobtime  prevexp
# id
# 1       m  03-Feb-52    15     3.0  57000.0   27000.0       98      144
# 2       m  23-May-58    16     1.0  40200.0   18750.0       98       36
# 3       f  26-Jul-29    12     1.0  21450.0   12000.0       98      381
# 4       f  15-Apr-47     8     1.0  21900.0   13200.0       98      190
# 5       m  09-Feb-55    15     1.0  45000.0   21000.0       98      138

# %%
a.plot()

# %%
a.plot.bar('jobcat','salary')

# %%
a.plot.hist('salary',alpha=.8)

# %%
a.boxplot(column=['salary','salbegin'])

# %%
a.plot.kde()

# %%
a.plot.area(y='salary')

# %%
b=a.drop(['gender','bdate'],axis=1)

# %%
b.head()
# Out:
#     educ  jobcat   salary  salbegin  jobtime  prevexp
# id
# 1     15     3.0  57000.0   27000.0       98      144
# 2     16     1.0  40200.0   18750.0       98       36
# 3     12     1.0  21450.0   12000.0       98      381
# 4      8     1.0  21900.0   13200.0       98      190
# 5     15     1.0  45000.0   21000.0       98      138

# %%
b.plot.kde();
